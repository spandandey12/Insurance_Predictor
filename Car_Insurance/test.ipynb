# %%
from Car_Insurance.training import result
print(result(18, 0.2, 12, 2, 0, "suv"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from Car_Insurance.training import result
#       2 print(result(18, 0.2, 12, 2, 0, "suv"))
#
# ModuleNotFoundError: No module named 'Car_Insurance'

# %%
from Car_Insurance.training import CarInsurance

# Create an object
model = CarInsurance()

# Test the quote function
quote = model.quote_display(
    age=30,
    annual_km=15000,
    car_age=5,
    exp_years=10,
    num_accidents=1,
    vehicle_type="suv"
)

print("Predicted premium:", quote)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from Car_Insurance.training import CarInsurance
#       3 # Create an object
#       4 model = CarInsurance()
#
# ModuleNotFoundError: No module named 'Car_Insurance'
